# %% [markdown]
# #Facial Keypoint Recognition using  MLP Neural Networks with 1-hidden layer
#
# ----
#
#
# ----
#
# Preface:
#
# **I will not be presenting using this notebook,** I will be taking snippets of code from it as well as from python files I have created and putting them into slides - however - since I used this notebook for some of my analysis as well as to create plots and pictures for the presentation slides, and since I need to submit it along with all of the other files I used, I am doing my best to make sure it is nice and organized for any viewer of it. Long story short: **This notebook contains snippets of code as well as analysis on networks**
#
# I will admit that for the good majority of March I had been training neural networks inside of this notebook - however - after trying to train a larger network and having my computer use 80% of it's memory because FireFox grew to 6 gigabytes and stopped responding, eventually crashing (without finishing training the network) - I realized taking the training out of the notebook would be a better decision. I wish I had realized this sooner!
#
# Training neural networks takes time, the more simpler models I tinkered with could take 5-10 minutes to train. To avoid having to retrain networks every time I run the program, I elected to serialize the trained networks using the python package cPickle, so that I could load them later on to analyse the results without having to retrain them.
#
# By serializing neural networks, I can load them into this notebook already trained, and since the objects contain the training history, etc, not only can I make predictions on my data inside of this notebook, but I can plot things such as the learning curve (The loss over each epoch - using mean squared error or root mean squared error as a loss function).
#
#
#
#
#
#
# ###The Problem:
#
#   >- [Kaggle Competition](https://www.kaggle.com/c/facial-keypoints-detection)
#   >- Regression problem
#
#
# ###Observations:
#
#   >- Training Data : 7049 images  containing (x,y) coordinate labels for up to 15 keypoints (Some missing keypoints in the data)
#   >- Test data: 1783 images without (x,y) coordinate labels.
#
#
# ###Goal:
#
# Ultimately, the goal is to create an artificial neural network that approximates some function  $$f X \rightarrow y$$ where $X$ is the input 9216 pixels of a 96x96 dimension image of a face, and $y$ is a set of 15 (x,y) coordinate values corresponding to the keypoints of the face in the picture.

# %% [markdown]
# ####Python Packages Used:

# %%
from pandas.io.parsers import read_csv #to read in our data to a dataframe
import numpy as np
import cPickle as pickle #cpickle in order to serialize neural networks - save the weights
from sklearn.utils import shuffle #shuffling the data for train, test split
from lasagne import layers #For creating layers of the neural network
from lasagne.updates import nesterov_momentum #For accelerated gradient descent
from lasagne.nonlinearities import sigmoid
from nolearn.lasagne import NeuralNet #For creating the neural network
import os.path #For getting the path to files on the computer
import matplotlib.pyplot as plt #For plotting images / graphs
import theano

# %%
# inline plotting in the notebook
# %matplotlib inline

# %% [markdown]
# ###Preprocessing:
#
# Kaggle links to a great tutorial - Daniel Nouri, the creator of nolearn (A python package that wraps neural network libraries) did a tutorial on using Convolutional Neural Networks to predict facial keypoints (on this dataset). In his tutorial he has sample code for loading and preprocessing the data, as well as some classes that can be used to implement Early Stopping (more on that in a bit...) as well as adjusting variables in the network as it trains (more on that in a bit...). I will use his [load() function from the tutorial](http://danielnouri.org/notes/2014/12/17/using-convolutional-neural-nets-to-detect-facial-keypoints-tutorial/#the-data)
#
# The following is done to process the data and get it ready to be modeled:
#
#     1. Data is loaded into a pandas dataframe to be processed.
#     2. The image column is converted into a numpy array. Originally it was string sperated pixel values, but we want a numpy array of floats so that we can manipulate it and use it for our neural network models.
#     3. If Specific columns are specified, only the columns specified are loaded from the data for processing. This comes in handy later when I train multiple networks for specific keypoints!
#     4. If drop missing is true, Columns with missing values are dropped (Leaving us with a little over ~2200 samples vs. the original ~7000
#     5. The pixel values scaled from [0, 255] to [0,1]
#     6. If not loading test data, coordinate output values are scaled from [0,96] to [-1,1]
#     7. The Data is shuffled using a random seed for consistency during testing.
#     8. Numpy arrays for X (Image inputs) and y (target coordinate outputs) are returned, or just the X if it loading the kaggle test data.
#
#
# Here is the code that is used:

# %%
#Data files
FTRAIN = '../Data/training.csv'
FTEST = '../Data/test.csv'

        
def load(test=False, cols=None, drop_missing=True):
    """Loads data from FTEST if *test* is True, otherwise from FTRAIN.
    Pass a list of *cols* if you're only interested in a subset of the
    target columns. By default, samples with missing coordinates are dropped.
    """
    fname = FTEST if test else FTRAIN
    df = read_csv(os.path.expanduser(fname))  # load pandas dataframe

    # The Image column has pixel values separated by space; convert
    # the values to numpy arrays:
    df['Image'] = df['Image'].apply(lambda im: np.fromstring(im, sep=' '))

    if cols:  # get a subset of columns
        df = df[list(cols) + ['Image']]
   
    if (drop_missing):
        df = df.dropna()  # drop all rows that have missing values in them


    X = np.vstack(df['Image'].values) / 255.  # scale pixel values to [0, 1]
    X = X.astype(np.float32)

    if not test:  # only FTRAIN has any target columns
        y = df[df.columns[:-1]].values
        y = (y - 48) / 48  # scale target coordinates to [-1, 1]
        X, y = shuffle(X, y, random_state=65539)  # shuffle train data using seed for consistency
        y = y.astype(np.float32)
    else:
        y = None

    return X, y

#For loading 2d data
def load2d(test=False, cols=None):
    X, y = load(test=test)
    X = X.reshape(-1, 1, 96, 96)
    return X, y

# %%
X, y = load()

# %%
print "X shape: {}\ny shape: {}".format(X.shape, y.shape)
print "X: min, max = ({},{})\ny: min, max = ({},{})".format(X.min(), X.max(), y.min(), y.max())
print "Using {}% of the provided training data".format(X.shape[0]/7049.*100.)
# Out:
# X shape: (2140L, 9216L)
# y shape: (2140L, 30L)
# X: min, max = (0.0,1.0)
# y: min, max = (-0.920286595821,0.996020495892)
# Using 30.3589161583% of the provided training data

# %%
type(X)
# Out:
# numpy.ndarray

# %% [markdown]
# ####Sample Workflow for modelling networks:
#
# Here is the general idea of how you will model a network:

# %%
# Sample work flow :

#Load Data, processed
#X, y = load()

#Initialize the networok
#net = NeuralNet( 
#                    layers= ..
#                    params= ..
#               )

#Fit network with data
#net.fit(X,y)

#Load test data
#X = load(test=false)[0] 

#Make prediction
#y_pred = net.predict(X)

#...

# %% [markdown]
# So you'd load the data , fit the netwowrk on the data, make predictions, and do analysis/ evaluate...

# %% [markdown]
# ###Models
#
# ----
#
# I have elected to keep the structure of the network mostly the same for all the models I consider - i.e. I will use a Multilayer perceptron network with one hidden layer for the models.
#
# My choice for this structure was because:
#
# "The universal approximation theorem claims that the standard multilayer feed-forward
# networks  with  a  single  hidden  layer  that  contains  finite  number of  hidden neurons,
# and  with  arbitrary  activation  function are  universal  approximators  in  $C(R^{m})$. Kurt
# Hornik (1991) showed that it is not the specific choice of the activation function, but
# rather the
# multilayer feedforward architecture
# itself which gives neural networks the
# potential of being universal approximators. The output units are always assumed to be
# linear.  For notational convenience we shall explicitly formulate our results only for
# the case where there is only one output unit. (The general case can easily be deduced
# from the simple case.)" --http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.101.2647&rep=rep1&type=pdf
#
# [The Universal Approximation Theorem]http://deeplearning.cs.cmu.edu/pdfs/Cybenko.pdf
#
# The proof is rather in-depth, in fact, a whole class could probably be spent simply proving this theorem, so let's accept it and move on!
#
#
#
# ####Model 1: A MLP network with one hidden layer
#
# ----
#
# I used the Lasagne package which wraps Theano, a deep learning package, in order to create my networks.
#
# Here are the params for the first network:
#
# Parameters:
#   >- Loss function: MSE
#   >- Layers:
#    - Input layer ( Our image )
#    - Hiden layer
#    - Output layer ( The predicted keypoints )
#
#   >- Hidden layer parameters:
#    - Activation function: Sigmoid
#    - Number of units in the hidden layer: 100
#    - Update method: Nesterov momentum
#    - Momentum coefficient: 0.9
#    - Learning rate: 0.01
#   >- Output layer parameters:
#    - Output nonlinearity : None
#   >- Epoch paramaters:
#    - On epoch finished: EarlyStopping (patience = 50)
#
# Let's talk about these parameters.
#
# #####Loss Function
#
# The goal of the network as it trains is to mimize the mean squared error loss function  $$ \operatorname{MSE}=\frac{1}{n}\sum_{i=1}^n(\hat{Y_i} - Y_i)^2.$$ where $\hat{Y_i}$ is the predicted value for sample $i$ and $Y_i$ is the actual value for sample $i$, and $n$ is the number of samples.
#
# This is the one used by default in Lasagne NeuralNet. Kaggle evaluates submissions using the RMSE (Root mean squared error) however, as the RMSE punishes larger errors.
#
#
#
# #####Activation Function
#
# For the hidden layer I use a sigmoid activation function, which is defined as:  $f(t) = \dfrac{1}{1+e^{-t}}$  - you can find the implementation of it [here](https://github.com/Theano/Theano/blob/master/theano/tensor/nnet/sigm.py)
#
# By default, the lasagne NeuralNet will use the rectifier activation function if none is provided. The rectifier activation function is defined as $f(x) = max(0,x)$ where x is the input to the neuron. This appears to be the a standard activation function lately in deep learning (According to discussions with Daniel Nouri and others on the lasagne github repo issues/commits comments) but I found that it didn't perform as well as the sigmoid activation function with the network I created. Here is the pseudocode for it, however:
#
#
#     # rectify
#     def rectify(x):
#         # The following is faster than T.maximum(0, x),
#         # and it works with nonsymbolic inputs as well.
#         # Thanks to @SnipyHollow for pointing this out. Also see:
#         # http://github.com/benanne/Lasagne/pull/163#issuecomment-81765117
#         return 0.5 * (x + abs(x))
#
#
# #####Number of hidden units
#
#
# The number of hidden units is exactly what it sounds like: It is the number of units, aka neurons, that comprise the hidden layer. There have been I used GridSearchCV from sklearn in order to pick a number of hidden units for the network. How this works is, you pass in your estimator (The neural network) as well as a parameter grid and number of cross validation folds, and then it exhaustively searches over this grid of paramters for the best choice. My parameter grid was hidden unit numbers [100, 150, 200, 250, 300] and I used 2-fold cross validation. It found that 100 hidden units was the best performing.
#
# [I searched for a method to determine the hidden unit size, and found rule of thumb examples but there is no clear straightforward calculation to figure it out](http://stats.stackexchange.com/questions/181/how-to-choose-the-number-of-hidden-layers-and-nodes-in-a-feedforward-neural-netw)
#
# Daniel Nouri (Who is an expert in this field) used 100 for his example 1-hidden layer MLP network, so I figured searching for an optimum parameter close to that would be a good idea. I chose to look at the paramater choices [100,150,..,300] because it is not feasible to try out [100,101,..,299,300] as for every single paramater choice I need to retrain the neural network.... If I wanted to use gridsearch cross validation with paramters [100,101,...,299,300] I would need to train (300-100+1) networks and that would take days...
#
# Anyway, 100 did seem to be a good choice as I scored fairly well (#35 on the kaggle board) with that model.
#
#
# #####Update Method
#
# For an epoch, after the forward-pass has happened and the predicted values have been generated, the MSE is found and the weights are upadated accordingly. To updated, backpropagation happens (Theory in slides).
#
# [Backpropagation methods](http://page.mi.fu-berlin.de/rojas/neural/chapter/K8.pdf)
#
# I am using the [Nesterov's momentum - accelerated gradient descent algorithm](http://www.cs.toronto.edu/~fritz/absps/momentum.pdf) since it is a well performing optimization algorithm to improve the rate of learning.
#
# ######Momentum
#
# The momentum coefficient is the fraction of the previous weight update to add to the current one. The values are between [0,1], and a higher momentum parameter can help increase the speed of convergence, but too high can risk overshooting the minimum. A small momentum parameter may make the network converge to a local minima as well as slow down the training. I've used the coefficient that Daniel Nouri uses, and later (For the next model) I will introduce the idea of slowly increasing the momentum while decreasing the learning rate instead of using a static coefficient for both.
#
# #####Learning rate
#
# This is essentially a coefficient determining how big of a step it takes in the new direction. If you use too high of a value it will converge to a local minimum too quickly and that will be that, I have used 0.01 as that is the paramter that Daniel Nouri used - and later, I will introduce the concept of adjusting the value as the network trains, decreasing it - since you want a higher learning rate at the start to get close to convergence and then a lower rate at the end to keep training it!
#
# #####Output Nonlinearity
#
# This is a misnomer. Lasagne NeuralNet has a nonlinearity paramter - this is the activation function of the output layer - however - it is a linear combination of the activations in the hidden layer, not a nonlinear function.
#
# #####Early Stopping
#
# The idea behind early stopping is that after you've been trainig your neural network for a while and the validation loss has not improved, that is a sign that it is not going to generalize any further, and you should stop early! How it works is you pass in a patience value, and after each epoch, it looks at the current validation loss, and if the current validation loss was worse than the (patience) number of epochs ago, it updates the weights to the weights of the best epoch (from the patience number of epochs ago) and stops training. This prevents overfitting as well as cuts training time down since the arbitrary number of epochs I am training to may not always be reached.
#
#
#
# #####Putting it all together
#
# here is the code that is used to create the network, perform gridsearchCV in order to choose the number of hidden units, and then finally, refit on the number of hidden units with the best score, and serialize to a binary file to be loaded later.

# %%
#Neural Network # 1  - A MLP with 1 hidden layer
net1 = NeuralNet(
    layers=[  # three layers: one hidden layer
        ('input', layers.InputLayer),
        ('hidden', layers.DenseLayer),
        ('output', layers.DenseLayer),
        ],
    # layer parameters:
    input_shape=(None, 9216),  # 96x96 input pixels per batch
    hidden_num_units=100,  # number of units in hidden layer
    hidden_nonlinearity=sigmoid,
    output_nonlinearity=None,  # output layer uses identity function
    output_num_units=30,  # 30 target values
    # optimization params
    update=nesterov_momentum,
    update_learning_rate=0.01,
    update_momentum=0.9,
    regression=True, 
    max_epochs=1000,
    on_epoch_finished=[
        EarlyStopping(patience=50)
        ],
    verbose=1 #It will output the summary of each epoch if set to 1 - takes up a lot of memory in firefox if you keep it like this!
    )


#paramter grid for gridsearch cv
param_grid = {
'more_params': [{'hidden_num_units': 100}, {'hidden_num_units':150}, {'hidden_num_units': 200},
{'hidden_num_units': 250}, {'hidden_num_units': 300}]
}
 
#find net with best params , and then refit with all data on best net
gs = GridSearchCV(net1, param_grid, cv=2, refit=True, verbose=4)

#Load data
X,y=load()
#Fit CV model
gs.fit(X,y)

#serialize model
with open('net1_gridsearch.pickle', 'wb') as f:
    # we serialize the gridsearch model, as it also has the fitted neural network with best hidden unit number:
    pickle.dump(gs, f, -1)
    #if you just want to save the best estimator - ie - the neural network itself - without the gridsearch info:
    #pickle.dump(gs.best_estimator_, f, -1)

# %% [markdown]
# The following is the sample Early Stopping class, courtesy of Daniel Nouri: If you want to load the pickled neural net, you need to run this cell, as the pickled net includes an instantiated earlystopping object inside of it and it wont load of the class is not defined in the program.

# %%
class EarlyStopping(object):
    def __init__(self, patience=100):
        self.patience = patience
        self.best_valid = np.inf
        self.best_valid_epoch = 0
        self.best_weights = None

    def __call__(self, nn, train_history):
        current_valid = train_history[-1]['valid_loss']
        current_epoch = train_history[-1]['epoch']
        if current_valid < self.best_valid:
            self.best_valid = current_valid
            self.best_valid_epoch = current_epoch
            self.best_weights = [w.get_value() for w in nn.get_all_params()]
        elif self.best_valid_epoch + self.patience < current_epoch:
            print("Early stopping.")
            print("Best valid loss was {:.6f} at epoch {}.".format(
                self.best_valid, self.best_valid_epoch))
            nn.load_weights_from(self.best_weights)
            raise StopIteration()


##These are for later...
#For shared learning/update rates
def float32(k):
    return np.cast['float32'](k)

            
#http://danielnouri.org/notes/2014/12/17/using-convolutional-neural-nets-to-detect-facial-keypoints-tutorial/#changing-learning-rate-and-momentum-over-time
class AdjustVariable(object):
    def __init__(self, name, start=0.03, stop=0.001):
        self.name = name
        self.start, self.stop = start, stop
        self.ls = None

    def __call__(self, nn, train_history):
        if self.ls is None:
            self.ls = np.linspace(self.start, self.stop, nn.max_epochs)

        epoch = train_history[-1]['epoch']
        new_value = float32(self.ls[epoch - 1])
        getattr(nn, self.name).set_value(new_value)

# %% [markdown]
# ###Model 1 evaluation:
#
# ----
#
# I will now load the fitted neural network model and analyze how well it peformed.
#
# Before I do that, however, I will load sample images and show the sample keypoints - to give a better idea of the problem we are modelling!

# %%
#Load our data

X,y = load()

# %%
#First, get the first 16 images and 16 sets of coordinates,
#Reshaping our 1-d array of  9216 pixels to a 2-d array of 96x96 pixels 
Sample_X = [x.reshape(96,96) for x in X[:16]]
Sample_y = y[:16]

#Set up our figure: a 4x4 grid of images.
fig, ((ax1, ax2, ax3, ax4), \
      (ax5, ax6, ax7, ax8), \
      (ax9, ax10, ax11, ax12), \
     (ax13, ax14, ax15, ax16)) = plt.subplots(nrows = 4, ncols= 4, sharex=False, sharey=False)
fig.set_size_inches(12,12)


#For each axis plot the corresponding image and keypoints
for x, ax in enumerate([ax1, ax2, ax3, ax4, ax5, ax6,  ax7,  ax8,  ax9,  ax10,  ax11,  ax12,  ax13,  ax14,  ax15,  ax16]):
    #Get image were' going to plot on the current axis of the subplot
    IMG = Sample_X[x]
    #Get keypoint coords for current image
    coords = Sample_y[x]
    #Scatter the coords on the figure
    ax.scatter(coords[0::2] * 48 + 48, coords[1::2] * 48 + 48, color='r', marker='x', s=20)
    #Show the image on the figure
    ax.imshow(IMG, cmap='gray')
plt.suptitle("Facial Keypoints")
plt.show()

# %% [markdown]
# The red xs on the images represent the target (x,y) coordinate output for each keypoint.

# %% [markdown]
# ####Problem:
#
# ----
# There is missing data: A lot of it! Some of the images have less than 15 pairs of coordinates - in fact, if we only consider samples which have all 15 coordinate pairs.. we only have ~30% of the original data.

# %% [markdown]
# ----
#
# ####Why is missing data a problem?
#
# ----
#
# If we model just using the samples without missing data points, the neural network will overfit - modelling the noise in our data - and it will be harder to train the network to generalize to any given picture of a face!
#
# ####Reducing the amount of overfitting in our model
#
# ----
#
# For this first model, I used Early Stopping in order to reduce the amount it overfits, as described earlier on in this notebook.
#
# There is another thing we can do, however: Train specialized networks, for subsets of the 15 coordinates - allowing us to use more of the sample training data! More on this later... It's time to load our first network into the notebook and analyse it's performance!

# %%
#Load the serialized gridsearchCV object which contains our network.
net1_gridsearch = pickle.load(open('../Data/net1_gridsearch.pickle', 'rb'))
# Out:
#   InputLayer        	(None, 9216)        	produces    9216 outputs
#   DenseLayer        	(None, 100)         	produces     100 outputs
#   DenseLayer        	(None, 30)          	produces      30 outputs
#   InputLayer        	(None, 9216)        	produces    9216 outputs
#   DenseLayer        	(None, 100)         	produces     100 outputs
#   DenseLayer        	(None, 30)          	produces      30 outputs

# %%
#This just shows the params the gridsearch considered when finding the best model
net1_gridsearch.param_grid
# Out:
# {'more_params': [{'hidden_num_units': 100},
#   {'hidden_num_units': 150},
#   {'hidden_num_units': 200},
#   {'hidden_num_units': 250},
#   {'hidden_num_units': 300}]}

# %%
#Here are the best parameters:
print net1_gridsearch.best_params_
# Out:
# {'more_params': {'hidden_num_units': 100}}

# %%
#Print the best score (eg. Lowest MSE loss) as well as the kaggle evaluation score for it
print "The best score (Lowest MSE) was: " + str(net1_gridsearch.best_score_)
print "This translates to a RMSE (Kaggle evaluation) score of: " + str(np.sqrt(net1_gridsearch.best_score_) * 48.)
# Out:
# The best score (Lowest MSE) was: 0.0025870305397
# This translates to a RMSE (Kaggle evaluation) score of: 2.44141728581

# %% [markdown]
# So our first model, using 100 hidden units, and the other parameters listed above in this notebook, performed quite decently: A 2.44 on the Kaggle leaderboard would be place \#13 at time of writing this! Of course, since the Kaggle submission introduces even more samples to test the network on, it will probably end up being a bit higher.. We will see soon!
#
# Let's now get our neural network model:

# %%
net1 = net1_gridsearch.best_estimator_

# %%
net1
# Out:
# NeuralNet(X_tensor_type=<function matrix at 0x000000000C46FEB8>,
#      batch_iterator_test=<nolearn.lasagne.BatchIterator object at 0x0000000020EEC4A8>,
#      batch_iterator_train=<nolearn.lasagne.BatchIterator object at 0x0000000020EEC4E0>,
#      eval_size=0.2,
#      hidden_nonlinearity=<theano.tensor.elemwise.Elemwise object at 0x0000000020EEC550>,
#      hidden_num_units=100, input_shape=(None, 9216),
#      layers=[('input', <class 'lasagne.layers.input.InputLayer'>), ('hidden', <class 'lasagne.layers.dense.DenseLayer'>), ('output', <class 'lasagne.layers.dense.DenseLayer'>)],
#      loss=<function mse at 0x000000001780FB38>, max_epochs=1000,
#      more_params={'hidden_num_units': 100},
#      on_epoch_finished=[<__main__.EarlyStopping object at 0x0000000020EEC470>],
#      on_training_finished=(), output_nonlinearity=None,
#      output_num_units=30, regression=True,
#      update=<function nesterov_momentum at 0x000000001780FEB8>,
# ...

# %% [markdown]
# Great! As you can see, it has 100 hidden units, and the parameters listed earlier on.

# %% [markdown]
# #### Learning Curve
#
# Here's a function for plotting the learning curve for our models..

# %%
#Plot learning curve using specified loss function (RMSE or MSE)
def plot_acc(net, label, loss='RMSE'):
    if loss == 'RMSE':
        train_loss = np.sqrt(np.array([i["train_loss"] for i in net.train_history_]))*48.
        valid_loss = np.sqrt(np.array([i["valid_loss"] for i in net.train_history_]))*48.
        plt.ylim(0,5)

    elif loss == 'MSE':
        train_loss = np.array([i["train_loss"] for i in net.train_history_])
        valid_loss = np.array([i["valid_loss"] for i in net.train_history_])
        plt.yscale("log")

    plt.plot(train_loss, linewidth=2, label="train loss")
    plt.plot(valid_loss, linewidth=2, label="valid loss")
    plt.grid()
    plt.legend()
    plt.xlabel("epoch")
    plt.ylabel(loss)

    plt.suptitle(loss+ " learning curve for "+label)
    plt.show()    

plot_acc(net1, "net 1:", 'MSE')
plot_acc(net1, "net 1:", 'RMSE')

# %% [markdown]
# This is simply plotting the loss over each epoch, for the MSE as well as RMSE (Kaggle's evaluation)

# %% [markdown]
# ####Sample prediction plotted
#
# ----
#
# Using the fit neural network, I will now show an example of it making a prediction - on our training data:
#
# Please note, since we scale the predicted target output to [-1,1], from [0,96], before plotting them, we must scale back to [0,96] using $y * 48 + 48$

# %%
#Make predictions on our training data. 
y_pred = net1.predict(X)
#Get the image
IMG = X[0].reshape(96,96)
plt.figure()
#Get keypoint coords for current image predicted values
coords = y_pred[0]
#Scatter the coords on the figure
plt.scatter(coords[0::2] * 48 + 48, coords[1::2] * 48 + 48, color='r', marker='x', s=20)
#Show the image on the figure
plt.imshow(IMG, cmap='gray')
plt.suptitle("net1: Facial Keypoints - Predicted")
plt.show()
plt.figure()
#Get keypoint coords for current image
coords = y[0]
#Scatter the coords on the figure
plt.scatter(coords[0::2] * 48 + 48, coords[1::2] * 48 + 48, color='r', marker='x', s=20)
#Show the image on the figure
plt.imshow(IMG, cmap='gray')
plt.suptitle("net1: Facial Keypoints - Actual")
plt.show()

# %% [markdown]
# As you can see, visually, it does an alright job! The nose is a little off, though... Let's now plot it for a test data image (Which we do not have labels for, since we're submitting it to kaggle!)

# %%
#Load test data!
X, y = load(test=True)
#Make predictions on test data...
y_pred = net1.predict(X)

#Plot the image
plt.figure()
IMG = X[0].reshape(96,96)

#Get keypoint coords for current image
coords = y_pred[0]
#Scatter the coords on the figure
plt.scatter(coords[0::2] * 48 + 48, coords[1::2] * 48 + 48, color='b', marker='x', s=20)
#Show the image on the figure
plt.imshow(IMG, cmap='gray')
plt.suptitle("net1: Facial Keypoints - Prediction on Kaggle submission data (sample)")
plt.show()

# %% [markdown]
# Look at that! This is data we do not have labels for, but, visually inspecting, we can see the keypoints plotted seem to almost hit the mark. There's only one way to figure out how well our model performs on kaggle, however, and that is to make a submission......

# %% [markdown]
# ####Submitting the model for Kaggle evaluation
#
# ----
#
# The test data that we submit predictions for is ~1700 images... Unfortunately, it's not as straightforward as simply predicting, writing values to a csv and submitting...
#
# This is because the submission example picks and chooses specific keypoints from each sample, so before submitting, I need to filter out any keypoint the submission example does not include from the sample test data...

# %%
#Making a kaggle submission:

#load the lookup table
facial_id = read_csv('../Data/facial_idlookuptable.csv')
#get a dataframe of our training data... we need it to get index numbers
df = read_csv('../Data/training.csv')


#We want to map all the feature names from ['feature_x', 'feature_y', etc.] 
#to [0,1,..,29] since there are 15 x,y coordinate sets..
for x, feat in enumerate(df.columns.tolist()[:-1]):
    facial_id.FeatureName[facial_id.FeatureName == feat] = x
# Out:
# C:\Anaconda\lib\site-packages\IPython\kernel\__main__.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#Now we load our Test data into the X

X = load(test=True)[0]

#Make predictions
y_pred = net1.predict(X)

#scale predictions from [-1,1] back to [0,96]
y_pred = (y_pred * 48) + 48

#Filter the predicted values to just the ones Kaggle wants
preds =  [y_pred[x-1][facial_id[facial_id.ImageId == x].FeatureName] for x in np.unique(facial_id.ImageId)]

#Create a list with all of the prediction values, flattened from the preds ndarrays..
p=[]
for arr in preds: #for each array in our predictions
    for data in arr: #and for each predicted coordinate value in the array
        p.append(data)

# %%
print str(len(p)) # should be == 27124, since the kaggle submission is 27124 items
# Out:
# 27124

# %%
#Assigin our predicted values to the Location section in facial_id dataframe
facial_id.Location = p

# %%
#create submission file
submissionName = "submission_net1.csv" 
with open(submissionName, "wb") as f:
    f.write(facial_id[['RowId', 'Location']].to_csv(index=False))

# %% [markdown]
# And with that submitted, it performed reasonably well! The picture of my place on the leaderboard is in the slides - I was rank #35. of around 80 people with this submission.

# %% [markdown]
# ----
#
# ###Model 2: (Well, Model's' 2:) Specialized neural networks for subsets of facial keypoints!
#
#
# In my second model, well, models, I created 6 specialized neural networks, and introduced a new Adjust Variable feature, where every epoch the learning rate would decrease and the momentum coefficient would increase. At the end, I combined the predicted values of each set of coordinates into one big prediction array.

# %% [markdown]
#     So My net 2 is actually 6 nets working on subsets of the 15 keypoints. The code to create it should be found in NNets.py

# %%
#Load our 6 networks
net2_specialists = pickle.load(open('../Data/net-specialists.pickle', 'rb'))
# Out:
#   InputLayer        	(None, 9216)        	produces    9216 outputs
#   DenseLayer        	(None, 100)         	produces     100 outputs
#   DenseLayer        	(None, 4L)          	produces       4 outputs
#   InputLayer        	(None, 9216)        	produces    9216 outputs
#   DenseLayer        	(None, 100)         	produces     100 outputs
#   DenseLayer        	(None, 2L)          	produces       2 outputs
#   InputLayer        	(None, 9216)        	produces    9216 outputs
#   DenseLayer        	(None, 100)         	produces     100 outputs
#   DenseLayer        	(None, 6L)          	produces       6 outputs
#   InputLayer        	(None, 9216)        	produces    9216 outputs
#   DenseLayer        	(None, 100)         	produces     100 outputs
#   DenseLayer        	(None, 2L)          	produces       2 outputs
#   InputLayer        	(None, 9216)        	produces    9216 outputs
#   DenseLayer        	(None, 100)         	produces     100 outputs
# ...

# %% [markdown]
# net2_specialists is an ordered dictionary of the 6 neural networks. I will create a list of tuples containing each network and the associated keypoints the network has been trained to predict.

# %%
net2 = [x for x in net2_specialists.iteritems()]
labels = [x[0] for x in net2]

# %%
for x,net in enumerate(net2):
    print "Specialized network #" +str(x+1) +" is trained on the keypoints:"
    print labels[x]
    print
# Out:
# Specialized network #1 is trained on the keypoints:
# ('left_eye_center_x', 'left_eye_center_y', 'right_eye_center_x', 'right_eye_center_y')
#
# Specialized network #2 is trained on the keypoints:
# ('nose_tip_x', 'nose_tip_y')
#
# Specialized network #3 is trained on the keypoints:
# ('mouth_left_corner_x', 'mouth_left_corner_y', 'mouth_right_corner_x', 'mouth_right_corner_y', 'mouth_center_top_lip_x', 'mouth_center_top_lip_y')
#
# Specialized network #4 is trained on the keypoints:
# ('mouth_center_bottom_lip_x', 'mouth_center_bottom_lip_y')
#
# Specialized network #5 is trained on the keypoints:
# ('left_eye_inner_corner_x', 'left_eye_inner_corner_y', 'right_eye_inner_corner_x', 'right_eye_inner_corner_y', 'left_eye_outer_corner_x', 'left_eye_outer_corner_y', 'right_eye_outer_corner_x', 'right_eye_outer_corner_y')
#
# Specialized network #6 is trained on the keypoints:
# ...

# %%
#load networks into list
net2_nets = [x[1] for x in net2]

# %%
#create variables for each network
net2_eyes = net2_nets[0] # eye centers
net2_nose = net2_nets[1] # nose tips
net2_mouth1 = net2_nets[2] # mouth corners and tops
net2_mouth2 = net2_nets[3] #mouth bottom center
net2_eyes2 = net2_nets[4] #eye corners
net2_eyebrows = net2_nets[5] # eyebrows

net2_labels = ['\'Eye centers\'', '\'Nose tips\'', '\'Mouth corners and tops\'', '\'Mouth bottom center\'', '\'Eye corners\'', '\'Eyebrows\'']

# %% [markdown]
# Lets first take a look at the learning curves for each of our specialized networks: Did some perform better or worse than others?

# %%
def plot_accs(nets, labels, loss='RMSE'):
    fig = plt.figure()
    for x in range(6):
        
        if loss == 'RMSE':
            train_loss = np.sqrt(np.array([i["train_loss"] for i in nets[x].train_history_]))*48.
            valid_loss = np.sqrt(np.array([i["valid_loss"] for i in nets[x].train_history_]))*48.
            plt.ylim(0, 5)
    
        elif loss == 'MSE':
            train_loss = np.array([i["train_loss"] for i in nets[x].train_history_])
            valid_loss = np.array([i["valid_loss"] for i in nets[x].train_history_])
            plt.yscale("log")
            plt.ylim((1e-3*0.5), 1e-1*0.2)
        plt.plot(train_loss, linewidth=2, label="train loss for: "+labels[x], ls='--')
        plt.plot(valid_loss, linewidth=2, label="valid loss for: "+labels[x])
    fig.set_size_inches(16,12)
    plt.grid()
    plt.xlabel("epoch - is different for each specialized network due to early stopping")
    plt.ylabel(loss)
    plt.suptitle(loss+ " learning curve for specialized networks")
    plt.legend(loc='best')
    plt.show()    

plot_accs([x[1] for x in net2], labels=net2_labels)

# %% [markdown]
# So, as you can see, some specialists were better than others in predicting their specific keypoints. Further training could be done to fine-tune each individual specialized network, but I am running out of time! Let's see what the MSE / RMSE values are for these networks, on the training data. After that, I'll put together a kaggle submission with the kaggle test data.

# %% [markdown]
# By default, the Neural Net used 20% of the train data as validation data,
# So I will do a train-test split with 20%, and show the reuslting train vs. validation scores for each specialized neural net.

# %%
print "labels\t|\ttrain score\t|\tvalid score"
for x, net in enumerate ([net2_eyes, net2_nose, net2_mouth1, net2_mouth2, net2_eyes2, net2_eyebrows]):
    X, y = load(cols=labels[x])
    
    X_train, X_valid, y_train, y_valid =  net.train_test_split(X, y, eval_size=0.2)

    train_score = net.score(X_train, y_train)
    valid_score = net.score(X_valid, y_valid)
    train_score_rmse, valid_score_rmse = np.sqrt(train_score)*48., np.sqrt(valid_score)*48.
    
    print net2_labels[x] + "\t|\t"+str(train_score)+"\t|\t"+str(valid_score)
# Out:
# labels	|	train score	|	valid score
# 'Eye centers'	|	0.00174424204346	|	0.00304428217138
# 'Nose tips'	|	0.00344257359455	|	0.005985269282
# 'Mouth corners and tops'	|	0.00159532899415	|	0.00399073439391
# 'Mouth bottom center'	|	0.00331330332695	|	0.00583614665805
# 'Eye corners'	|	0.000931936667851	|	0.00145246363777
# 'Eyebrows'	|	0.00142408664489	|	0.00218300545633

# %% [markdown]
# So our best specialist was the 'Eye Corners' network, which trained on the following:

# %%
labels[4]
# Out:
# ('left_eye_inner_corner_x',
#  'left_eye_inner_corner_y',
#  'right_eye_inner_corner_x',
#  'right_eye_inner_corner_y',
#  'left_eye_outer_corner_x',
#  'left_eye_outer_corner_y',
#  'right_eye_outer_corner_x',
#  'right_eye_outer_corner_y')

# %% [markdown]
# And our worst specialist was the Nose Tips, which trained on:

# %%
labels[1]
# Out:
# ('nose_tip_x', 'nose_tip_y')

# %% [markdown]
# The average RMSE across the 6 networks was:
#
# 'Eye centers'valid score:
# RMSE (Kaggle's evaluation):2.64840067264
#
# 'Nose tips'valid score:
# RMSE (Kaggle's evaluation):3.71349706149
#
# 'Mouth corners and tops'valid score:
# RMSE (Kaggle's evaluation):3.03226846496
#
# 'Mouth bottom center'valid score:
# RMSE (Kaggle's evaluation):3.66694449101
#
# 'Eye corners'valid score:
# RMSE (Kaggle's evaluation):1.82933764555
#
# 'Eyebrows'valid score:
# RMSE (Kaggle's evaluation):2.24268690891

# %%
print "The average validation loss (RMSE) is: " + str((2.64840067264 +3.71349706149+3.03226846496+3.66694449101+1.82933764555+2.24268690891)/6.)
# Out:
# The average validation loss (RMSE) is: 2.85552254076

# %% [markdown]
# Of course, if I had time, I would like to work on fine-tuning each specialist in order to produce a better result, but let's make a submission and see how it does overall.
#
# Here's pseudocode for how I'll put together the prediction array, to make the submission, since each network outputs a bunch of arrays corresponding to specific indices of the prediction array I should have:
#
#     preds = []
#     For each specialized network, net:
#         Load X data for cols corresponding to net
#     preds.append([net.predict(X)])
#     swap indices for two of the predictions i, j to be in the same order as the submission data
#     preds[i] = preds[i][:, 0, 1, 4, 5, 2, 3, 6, 7]
#     preds[j] = preds[j][:, 0, 1, 4, 5, 2, 3, 6, 7]
#     preds = np.hstack(preds)
#     create submission the same way we created submission 1 (code earlier on in the ipynb)

# %%
#The horizontal columns of the prediction matrix I am creating should correspond to the following:
ylabels = df.columns.tolist()[:-1]
for a, b in enumerate(df.columns.tolist()[:-1]):
    print a 
    print b
# Out:
# 0
# left_eye_center_x
# 1
# left_eye_center_y
# 2
# right_eye_center_x
# 3
# right_eye_center_y
# 4
# left_eye_inner_corner_x
# 5
# left_eye_inner_corner_y
# 6
# left_eye_outer_corner_x
# 7
# left_eye_outer_corner_y
# 8
# right_eye_inner_corner_x
# 9
# right_eye_inner_corner_y
# 10
# right_eye_outer_corner_x
# 11
# right_eye_outer_corner_y
# 12
# left_eyebrow_inner_end_x
# 13
# left_eyebrow_inner_end_y
# 14
# left_eyebrow_outer_end_x
# 15
# left_eyebrow_outer_end_y
# 16
# right_eyebrow_inner_end_x
# 17
# right_eyebrow_inner_end_y
# 18
# right_eyebrow_outer_end_x
# 19
# right_eyebrow_outer_end_y
# 20
# nose_tip_x
# 21
# nose_tip_y
# 22
# mouth_left_corner_x
# 23
# mouth_left_corner_y
# 24
# mouth_right_corner_x
# 25
# mouth_right_corner_y
# 26
# mouth_center_top_lip_x
# 27
# mouth_center_top_lip_y
# 28
# mouth_center_bottom_lip_x
# 29
# mouth_center_bottom_lip_y

# %% [markdown]
# Looking back at the features of each specialist neural network...
#
# ----
#
# ('left_eye_center_x', 'left_eye_center_y', 'right_eye_center_x', 'right_eye_center_y')
#
# correspond to indices of pred array: 0 1 2 3
#
# ('nose_tip_x', 'nose_tip_y')
#
# correspond to indices of pred array: 20, 21
#
# ('mouth_left_corner_x', 'mouth_left_corner_y', 'mouth_right_corner_x', 'mouth_right_corner_y', 'mouth_center_top_lip_x', 'mouth_center_top_lip_y')
#
# correspond to indices of pred array: 22 23 24 25 26 27
#
#
# ('mouth_center_bottom_lip_x', 'mouth_center_bottom_lip_y')
#
# correspond to indices of pred array: 28 29
#
#
# ('left_eye_inner_corner_x', 'left_eye_inner_corner_y', 'right_eye_inner_corner_x', 'right_eye_inner_corner_y',
# 'left_eye_outer_corner_x', 'left_eye_outer_corner_y', 'right_eye_outer_corner_x', 'right_eye_outer_corner_y')
#
# correspond to indices of pred array: 4 5 8 9 6 7 10 11
#
# ('left_eyebrow_inner_end_x', 'left_eyebrow_inner_end_y', 'right_eyebrow_inner_end_x', 'right_eyebrow_inner_end_y', 'left_eyebrow_outer_end_x', 'left_eyebrow_outer_end_y', 'right_eyebrow_outer_end_x', 'right_eyebrow_outer_end_y')
#
# correspond to indices of pred array: 12 13 16 17 14 15 18 19
#
#
# In order to do this, I use a np.hstack to stack horizontally, after swapping some of the indices in the original arrays..

# %%
#These two are currently out of order compared to the order of the submission data 
#Swapping 2 3 with 4 5 fixes taht.
y_pred_eyes2_proper = y_pred_eyes2[:, [0, 1, 4, 5, 2, 3, 6, 7]]
y_pred_eyebrows_proper = y_pred_eyebrows[:, [0, 1, 4, 5, 2, 3, 6, 7]]

#Now we can make our big array of all the predictions!
y_pred_specialists = np.hstack([y_pred_eyes, y_pred_eyes2_proper,
           y_pred_eyebrows_proper, y_pred_nose,
           y_pred_mouth1, y_pred_mouth2])

# %%
print y_pred_specialists.shape #Should be 1783 rows of 30 values each
# Out:
# (1783L, 30L)

# %%
#Again, we rescale from [-1,1] to [0,96]
y_pred_specialists = (y_pred_specialists * 48) + 48

print "Min: " + str( y_pred_specialists.min()) # SHould not be less than 0 
print "Max: " + str( y_pred_specialists.max()) # Should not be greater than 96

#Create the list of filtered out values for the kaggle submission
preds =  [y_pred_specialists[x-1][facial_id[facial_id.ImageId == x].FeatureName] for x in np.unique(facial_id.ImageId)]
# Out:
# Min: 6.00268813051
# Max: 94.1639422056

# %%
#fill list with our prediction values that we will submit
p=[]
for arr in preds:
    for data in arr:
        p.append(data)
#Assigin our predicted values to the Location section in facial_id dataframe
facial_id.Location = p

# %%
#create submission file
submissionName = "submission_specialists.csv" 
with open(submissionName, "wb") as f:
    f.write(facial_id[['RowId', 'Location']].to_csv(index=False))

# %% [markdown]
# I was quite delighted to see that when submitting predictions with this 6-model combination, I jumped another 15 spots on the leader board! At the time of submision, I am ranked #20. on the board with a $RMSE = 3.07987$ on the Kaggle test data!!!

# %% [markdown]
# ####Conclusion:
#
# I modelled one hidden layer MLP networks on this data, and was able to produce models that scored relatively well. Further improvements could be found with the specialized networks I created by fine-tuning the parameters individually, and other models that would be well-suited to this data would include Convolutional Neural Networks (see the theory slides).
